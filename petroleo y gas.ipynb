# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import FuncFormatter
import numpy as np

# %%
p_gas=[8.92,
6.72,
6.98,
8.86,
3.95,
4.39,
4.00,
2.75,
3.72,
4.37,
2.61,
2.49,
2.96,
3.16,
2.57,
2.01,
3.85,
6.37,
2.54,
]
año=[2005+i for i in range(19)]
nep=np.full(len(año),None)
e_petroleo=[15416919, 14881796, 15027399, 14233450, 12328866, 12607468, 12957860, 15085772, 17334291, 18639623, 17907265, 16572386, 15722295, 14656979, 12973942, 11770554, 11438199, 10189299, 8599810]
e_gas= [12535.69, 13433.54, 14301.38, 14895.13, 12786.80,14922.73, 16185.96, 18475.14, 21021.44, 22187.95,21998.81, 21144.53, 20531.91, 19178.87, 16893.15,16254.38, 16968.82, 15400.89, 13390.41]

exportaciones_brasil_gn=[1400.9,1619.4,	1453.9,	1020.5,	1285.6,	1643.3,	1363.3]
#exportaciones gas en millones de dolares
e_gdolares = [
    1086.5, 1667.8, 1971.2, 3159.1, 1967.6, 2797.8, 3884.9, 5478.5, 6113.4, 
    6011.1, 3770.4, 2049.1, 2581.3, 2970.4, 2719.9, 1989.3, 2249.1, 2973.4, 
    2049.7
]

df=pd.DataFrame({
    'Año':año,
    'Exportacion de petroleo (bariles)':e_petroleo,
    'Exportacion de gas (millones metros cubicos)':e_gas
})
df.set_index('Año', inplace=True)
df['exp gn brasil (millones de dolares)']=nep
df.loc[2017:2024,'exp gn brasil (millones de dolares)']=exportaciones_brasil_gn
df['exportaciones gas (millones de dolares)']=e_gdolares
df
# Out:
#       Exportacion de petroleo (bariles)  \
# Año
# 2005                           15416919
# 2006                           14881796
# 2007                           15027399
# 2008                           14233450
# 2009                           12328866
# 2010                           12607468
# 2011                           12957860
# 2012                           15085772
# 2013                           17334291
# 2014                           18639623
# 2015                           17907265
# 2016                           16572386
# 2017                           15722295
# 2018                           14656979
# 2019                           12973942
# 2020                           11770554
# 2021                           11438199
# 2022                           10189299
# 2023                            8599810
#
#       Exportacion de gas (millones metros cubicos)  \
# Año
# 2005                                      12535.69
# 2006                                      13433.54
# 2007                                      14301.38
# 2008                                      14895.13
# 2009                                      12786.80
# 2010                                      14922.73
# 2011                                      16185.96
# 2012                                      18475.14
# 2013                                      21021.44
# 2014                                      22187.95
# 2015                                      21998.81
# 2016                                      21144.53
# 2017                                      20531.91
# 2018                                      19178.87
# 2019                                      16893.15
# 2020                                      16254.38
# 2021                                      16968.82
# 2022                                      15400.89
# 2023                                      13390.41
#
#      exp gn brasil (millones de dolares)  \
# Año
# 2005                                None
# 2006                                None
# 2007                                None
# 2008                                None
# 2009                                None
# 2010                                None
# 2011                                None
# 2012                                None
# 2013                                None
# 2014                                None
# 2015                                None
# 2016                                None
# 2017                              1400.9
# 2018                              1619.4
# 2019                              1453.9
# 2020                              1020.5
# 2021                              1285.6
# 2022                              1643.3
# 2023                              1363.3
#
#       exportaciones gas (millones de dolares)
# Año
# 2005                                   1086.5
# 2006                                   1667.8
# 2007                                   1971.2
# 2008                                   3159.1
# 2009                                   1967.6
# 2010                                   2797.8
# 2011                                   3884.9
# 2012                                   5478.5
# 2013                                   6113.4
# 2014                                   6011.1
# 2015                                   3770.4
# 2016                                   2049.1
# 2017                                   2581.3
# 2018                                   2970.4
# 2019                                   2719.9
# 2020                                   1989.3
# 2021                                   2249.1
# 2022                                   2973.4
# 2023                                   2049.7

# %%
# Formatear eje Y para mostrar los valores completos
def millones(x, pos):
    return f'{int(x/1e6)}Mm'

plt.figure(figsize=(11, 6))
plt.plot(año, e_petroleo, label='Exportación de petróleo')
plt.gca().yaxis.set_major_formatter(FuncFormatter(millones))
plt.text(df.index[9], df.iloc[9,0], df.iloc[9,0], fontsize=11, color='red')
plt.text(df.index[2023-2005], df.iloc[2023-2005,0], df.iloc[2023-2005,0], fontsize=11, color='red')

plt.xlabel('Año')
plt.ylabel('Valor (en bariles)')
plt.title('Exportaciones Petróleo (bariles)')
plt.grid(True)
plt.xticks(año)
plt.legend()

# %%
plt.figure(figsize=(11, 6))
plt.plot(año, e_gas, label='Exportación de Gas')
plt.plot(año, e_gas, label='Exportación de Gas')

plt.xlabel('Año')
plt.ylabel('Valor (En Millones de metro cúbicos)')
plt.title('Exportaciones de Gas Natural En Millones de metro cúbicos')
plt.grid(True)
plt.xticks(año)
plt.legend()

# %%
plt.figure(figsize=(11, 6))
plt.plot(año, e_gdolares, label='Exportación de Gas')
plt.plot(año, df['exp gn brasil (millones de dolares)'], label='Exportación de Gas a Brasil')

plt.xlabel('Año')
plt.ylabel('Valor (En Millones de dolares estadounidenses)')
plt.title('Exportaciones de Gas Natural En Millones de dolares estadounidenses')
plt.grid(True)
plt.xticks(año)
plt.legend()

# %%
plt.figure(figsize=(11, 6))
plt.plot(año, p_gas, label='Precio de mercado del gas en dolares ')

plt.xlabel('Año')
plt.ylabel('Valor (En Millones de dolares estadounidenses)')
plt.title('Exportaciones de Gas Natural En Millones de dolares estadounidenses')
plt.grid(True)
plt.xticks(año)
plt.legend()
